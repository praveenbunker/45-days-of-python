# %% [markdown]
# <a href="https://colab.research.google.com/github/praveenbunker098-lgtm/45-days-of-python/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
print ("hiiiiiiiiiiiiiiiiiiiiiiiiiiii")

# %%
print("praveennnn")
print("hiiiiiiiiiiiiiiiiiii")

# %%
age = int(input("enter your age"))
print(age)
if age>= 18:
    if age== 18:
        print("you are exetly 18 year old!!")
    else:
        print("you older than 18 year old!!")

# %%
dict = {
            "movies": [
                "movie1",
                "movie2",
                "movie3",
            ]
    }

dict["movies"][0]= input("enter 1 st movie: \n")
dict["movies"][1]= input("enter 2 st movie: \n")
dict["movies"][2]= input("enter 3 st movie: \n")

print (dict["movies"])

# %%
dict = {
    "cars" : {
        "mahindra" : "" ,
        "honda" : "" ,
    }
}




dict["cars"]["mahindra"] = input("enter the name mahindra cars   ")
dict["cars"]["honda"] = input("enter the name honda cars   ")

a = dict["cars"]["honda"]
b = dict["cars"]["mahindra"]

if(a or b):
    print("cars are avilable")
else:
    print("cars are not avilable")

# %%
secret_number= 7
guess= int(input("Guess a number: "))
while guess !=secret_number:
    guess= int(input("Guess a number: "))

# %%
# Print table of 3 using while loop

num = 3
i = 1

while i <= 10:
    print(num, "x", i, "=", num * i)
    i += 1

# %%
number = int(input("Enter a number: "))
count = 1

while count != 11:
    print(number * count)
    count += 1

# %%
i = 0

dict = {"name": "name4"}

L = ["name1", "name2", "name3", "name4", "name5"]

while i < len(L):
    if dict["name"] == L[i]:
        print("name found")
    i += 1

# %% [markdown]
# FUNCTION == function is a certain block of code it will be execute when ever it is called **function**
#
# Function declare by keyword of *def*

# %%
def output():
  print("output")
output()

# %%
def praveen():
  for i in range(20):
    print("praveennnnnnnn")
praveen(

)

# %%
def praveen():
  for mm in range(5):
    print("praveen")
praveen()

# %%
def hello(x=10):
  print(x)
hello(20)
hello(30)
hello("jii")
hello([10,20,40,praveen])
hello({"name": "hello", "age":20})

# %%
def hello(x):
  print(x[0]["name"])
hello([{"name": "praveennnnnn"}])

# %%
def hello(x):
  return x
hello(10)

# %%
def hello(x):
  return (x[2][1])
a = hello([10,20,[30,40]])
print(a)

# %%
def hello(x,y):
  print(x,y)
hello(10,20)

# %%
def hello(x,y):
  print(x[1],y[1])

hello([10,20],[30,40])

# %%
def table(x):
  for i in range(1,11):
    print(f"{x}*{i}={x*i}")

table(70)

# %%
num = 100
def input_number():
  global own_num
  own_num = 50
  result= int(input("enter a number:")) * own_num
  return result
print(input_number())
print(own_num)

# %%
number = int(input("Enter a number: "))
count = 1

while count != 11:
    print(number * count)
    count += 1

# %%
secret_number= 10
guess= int(input("Guess a number: "))
while guess !=secret_number:
    guess= int(input("Guess a number: "))

# %%
t=[(a=(int(input("enter number"))))]
for i in t:
  if a==10:
    print("access")
  else:
    continue

# %%
c = 1

while True:
    a = int(input("Enter number: "))

    if a == 10:
        break
    else:
        c += 1

    if c == 3:
        print("c became 3")
# Out:
# Enter number: 12
# Enter number: 12
# c became 3
# Enter number: 10

# %% [markdown]
# ## **syntax** variable and data **types**\

# %% [markdown]
# int ,*float* , str, bool

# %%
a = 10
print(a)
print(id(a))

b = 10
print(b)
print(id(b))
# Out:
# 10
# 11645640
# 10
# 11645640

# %%
#int
a = 10
print(a)
print (type(a))

#float
b = 10.1
print(b)
print(type(b))

#boolean
d = False
print(d)
print(type(d))
# Out:
# 10
# <class 'int'>
# 10.1
# <class 'float'>
# False
# <class 'bool'>

# %% [markdown]
# ## **type conversion and input/output**

# %%
#input fxn used to take input from user
#input fxn used for print the valuse of variable

# num = input("enter a number:")
# print(num)
# print(type(num))
# print(int(num) + 10)
# print(num + str(10))
# print(num + 10)



num1 = int(input("enter a number:"))
num2 = int(input("enter a second number"))
print(num1+num2)
print(type(num1,num2))
print(int(num1+num2) + 10)
# Out:
# enter a number:100
# enter a second number200
# 300
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6600/2274683270.py in <cell line: 0>()
#      14 num2 = int(input("enter a second number"))
#      15 print(num1+num2)
# ---> 16 print(type(num1,num2))
#      17 print(int(num1+num2) + 10)
#
# TypeError: type() takes 1 or 3 arguments

# %% [markdown]
# ## Operation and expression

# %%
# #arthmatic opr = + - * \\ \

# p = 10
# b = 20
# print(p*b)

# c = 20
# d = 30
# print(c - d)
# print(d - b)


# num1 = 10
# num2 = 2
# print(num1 / num2) #float



num3 = 10
num4 = 2
print(num3 // num4)
print(num3 % num4)  #remainder

num1 = int(input("enter a num1"))
num2 = int(input("enter a num2"))
print(num1  % num2)
# Out:
# 5
# 0
# enter a num119
# enter a num223
# 19

# %%
#relational operator -> True and False
# == , < , > , >= , <= , !=

a = 10
b = 5

print(a > b)    # True
print(a == b)   # False
print(a != b)   #true
print(a >= b)   #true
print(a <= b)   #false
# Out:
# True
# False
# True
# True
# False

# %%
#Assignment operator
a = 10

a += 5
print(a)   # 15

a *= 2
print(a)   # 30
# Out:
# 15
# 30

# %%
#logical operator
# and or not
#and

# a = 20
# b = -30
# print(a and b)
# print(b and a)
# print( a or b)
# print(not a)



#Server Monitoring
server_down = True
backup_active = False

if server_down and not backup_active:
    print("Critical Warning")


#bank loan
salary = 50000
credit_score = 800
if salary > 40000 and credit_score > 750:
  print("loan approved")

#Login Authentication
username = "admin"
password = "1234"

if username == "admin" and password == "1234":
    print("Login Successful")
# Out:
# Critical Warning
# loan approved
# Login Successful

# %% [markdown]
# BITWISE OPERATOR
# ### >> , << , & , !

# %%
a = 5
b = 2
print(a & b)
print(a << b)
print( a >> b)
# Out:
# 0
# 20
# 1

# %% [markdown]
# identity operator
#  is | is not

# %%
#example1
a = [1, 2]
b = [1, 2]

print(a == b)
print( a is b)
print(id(a))
print(id(b))

#example 2
name = 10
name1 = 10
print(name == name1)
print(name is name1)
print(id(name))
print(id(name1))

#example 3  (-5 to 256) -> both variable point on same address
num1 = 260
num2 = 260
print(num1 == num2)
print(num1 is num2)
# Out:
# True
# False
# 135011392827584
# 135011392826368
# True
# True
# 11645640
# 11645640
# True
# False

# %% [markdown]
# # *Condition statement:*

# %% [markdown]
# if else, while , for **
